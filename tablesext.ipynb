# %%
import camelot
import os
import pandas as pd
from tabulate import tabulate

# %%
tables = camelot.read_pdf("Food Calories List.pdf", pages= "all")

# %%
tables.n
# Out:
# 11

# %%
for table in tables:
    print(table.df)
# Out:
#                                                     0  \
# 0   per 100 grams \nBREADS & CEREALS \nPortion siz...
# 1                                 Bagel ( 1 average )
# 2                                  Biscuit digestives
# 3                                          Jaffa cake
# 4                           Bread white (thick slice)
# 5                             Bread wholemeal (thick)
# 6                                            Chapatis
# 7                                          Cornflakes
# 8                                        Crackerbread
# 9                                      Cream crackers
# 10                                           Crumpets
# 11                          Flapjacks basic fruit mix
# 12                                  Macaroni (boiled)
# 13                                             Muesli
# 14                                Naan bread (normal)
# 15                                   Noodles (boiled)
# ...

# %%
# Out:
#                                                     0  \
# 0   per 100 grams \nBREADS & CEREALS \nPortion siz...
# 1                                 Bagel ( 1 average )
# 2                                  Biscuit digestives
# 3                                          Jaffa cake
# 4                           Bread white (thick slice)
# 5                             Bread wholemeal (thick)
# 6                                            Chapatis
# 7                                          Cornflakes
# 8                                        Crackerbread
# 9                                      Cream crackers
# 10                                           Crumpets
# 11                          Flapjacks basic fruit mix
# 12                                  Macaroni (boiled)
# 13                                             Muesli
# 14                                Naan bread (normal)
# 15                                   Noodles (boiled)
# ...

# %%
for table in tables:
    print(table.df)
# Out:
#                                                    0               1  \
# 0  Vibrating Table – Datasheet \nEasier tamping –...
# 1  T\n1.  Product presentation \n \n \nBenefits \...
# 2
# 3
# 4                                                     Type of powder
# 5                                                             Sticky
# 6                                                           Bridging
# 7  2. Safety information and disclaimer \n! Do no...
# 8  +32 (0) 2 420 52 00 \nFeton International sprl...
#
#                                                    2                 3 4 5
# 0
# 1
# 2                                                     Model: \nSerial:
# 3
# 4                                            Benefit
# 5  If tamping sticky powder with a tamper tool, t...
# 6  Typically, very fine powders (flour-like) can ...
# 7
# 8

# %%
tables.export("foo.html", f="html")
